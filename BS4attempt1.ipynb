# %% [markdown]
# <a href="https://colab.research.google.com/github/hcantekin/hcantekin.github.io/blob/main/BS4attempt1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import requests as r
import html5lib as html5lib
import bs4 as bs4

# %%
IntStats = r.get('https://www.internetlivestats.com/internet-users/')

# %%
print(IntStats.content)
# Out:
# b'\n\n\n\n\n<!DOCTYPE html><!--[if IE 8]> <html lang="en" class="ie8"> <![endif]--><!--[if IE 9]> <html lang="en" class="ie9"> <![endif]--><!--[if !IE]><!--> <html lang="en"> <!--<![endif]--> <head> <meta charset="utf-8"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=device-width, initial-scale=1"> <title>Number of Internet Users (2016) - Internet Live Stats</title><meta name="description" content="World Internet users by year and Internet users by Country. Live counter showing estimated current internet users and historical growth rate. Charts, infographics, and interesting info."><meta content="/internet-live-stats.gif" itemprop="image"><meta property="og:image" content="/internet-live-stats.gif" /><link rel="icon" href="https://www.internetlivestats.com/favicon.ico" type="image/x-icon"> <!-- Bootstrap --> <link href="/css/bootstrap.min.css" rel="stylesheet"><link href="/ils16.css" rel="stylesheet"><!-- font awesome --><link rel="stylesh
# ...

# %%
soup = bs4.BeautifulSoup(IntStats.content, 'html5lib')

# %%
print(soup.prettify())

# %%
table1 = soup.find('table-responsive')
table1

# %%
# Out:
# None
