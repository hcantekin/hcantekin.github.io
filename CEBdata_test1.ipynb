# %% [markdown]
# <a href="https://colab.research.google.com/github/hcantekin/hcantekin.github.io/blob/main/CEBdata_test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv('CEB_govexp.csv')

# %%
df
# Out:
#           Year  Total GE  GE Primary  GE Secondary
# 0   1998-01-01  4.942010         NaN           NaN
# 1   1999-01-01  4.579435         NaN           NaN
# 2   2000-01-01  4.868400         NaN           NaN
# 3   2001-01-01  5.077810   18.233320     19.469280
# 4   2002-01-01  5.179230   19.678880     20.524955
# 5   2003-01-01  5.066850   18.515400     20.531810
# 6   2004-01-01  4.845410   14.679820     21.129180
# 7   2005-01-01  4.813160   17.343360     21.074695
# 8   2006-01-01  4.696130   23.201875     19.828090
# 9   2007-01-01  4.595210   19.191810     20.196900
# 10  2008-01-01  4.839900   21.418090     22.409920
# 11  2009-01-01  4.958040   21.564240     23.355680
# 12  2010-01-01  4.733020   22.166110     23.174100
# 13  2011-01-01  4.569060   19.957590     22.015035
# 14  2012-01-01  4.451700   19.293605     20.722375
# 15  2013-01-01  4.554130   22.501625     22.533805
# 16  2014-01-01  4.610660   19.884640     23.070450
# ...

# %%
CEB_GE= list(df.T.to_dict().values())

CEB_GE
# Out:
# [{'Year': '1998-01-01',
#   'Total GE': 4.942009926,
#   'GE Primary': nan,
#   'GE Secondary': nan},
#  {'Year': '1999-01-01',
#   'Total GE': 4.579434872,
#   'GE Primary': nan,
#   'GE Secondary': nan},
#  {'Year': '2000-01-01',
#   'Total GE': 4.868400097,
#   'GE Primary': nan,
#   'GE Secondary': nan},
#  {'Year': '2001-01-01',
#   'Total GE': 5.077809811,
#   'GE Primary': 18.23332,
#   'GE Secondary': 19.46928},
#  {'Year': '2002-01-01',
#   'Total GE': 5.179230213,
#   'GE Primary': 19.67888,
#   'GE Secondary': 20.524955},
#  {'Year': '2003-01-01',
#   'Total GE': 5.066850185,
#   'GE Primary': 18.5154,
#   'GE Secondary': 20.53181},
#  {'Year': '2004-01-01',
#   'Total GE': 4.84540987,
#   'GE Primary': 14.67982,
#   'GE Secondary': 21.12918},
#  {'Year': '2005-01-01',
#   'Total GE': 4.813159943,
#   'GE Primary': 17.34336,
#   'GE Secondary': 21.074695},
#  {'Year': '2006-01-01',
#   'Total GE': 4.696129799,
#   'GE Primary': 23.201875,
#   'GE Secondary': 19.82809},
# ...

# %%
import json

# %%
open('CEB_govexp.json','w').write(json.dumps(CEB_GE))
# Out:
# 2032

# %%
CEB_GE
# Out:
# [{'Year': '1998-01-01',
#   'Total GE': 4.942009926,
#   'GE Primary': nan,
#   'GE Secondary': nan},
#  {'Year': '1999-01-01',
#   'Total GE': 4.579434872,
#   'GE Primary': nan,
#   'GE Secondary': nan},
#  {'Year': '2000-01-01',
#   'Total GE': 4.868400097,
#   'GE Primary': nan,
#   'GE Secondary': nan},
#  {'Year': '2001-01-01',
#   'Total GE': 5.077809811,
#   'GE Primary': 18.23332,
#   'GE Secondary': 19.46928},
#  {'Year': '2002-01-01',
#   'Total GE': 5.179230213,
#   'GE Primary': 19.67888,
#   'GE Secondary': 20.524955},
#  {'Year': '2003-01-01',
#   'Total GE': 5.066850185,
#   'GE Primary': 18.5154,
#   'GE Secondary': 20.53181},
#  {'Year': '2004-01-01',
#   'Total GE': 4.84540987,
#   'GE Primary': 14.67982,
#   'GE Secondary': 21.12918},
#  {'Year': '2005-01-01',
#   'Total GE': 4.813159943,
#   'GE Primary': 17.34336,
#   'GE Secondary': 21.074695},
#  {'Year': '2006-01-01',
#   'Total GE': 4.696129799,
#   'GE Primary': 23.201875,
#   'GE Secondary': 19.82809},
# ...
