# %% [markdown]
# <a href="https://colab.research.google.com/github/hcantekin/hcantekin.github.io/blob/main/Lecture4_cleaningdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv('API_NY.GDP.MKTP.KD.ZG_DS2_en_csv_v2_4666485.csv', skiprows=4)

# %%
df.head(2)
# Out:
#                   Country Name Country Code         Indicator Name  \
# 0                        Aruba          ABW  GDP growth (annual %)
# 1  Africa Eastern and Southern          AFE  GDP growth (annual %)
#
#       Indicator Code  1960      1961      1962      1963      1964      1965  \
# 0  NY.GDP.MKTP.KD.ZG   NaN       NaN       NaN       NaN       NaN       NaN
# 1  NY.GDP.MKTP.KD.ZG   NaN  0.239594  7.980768  5.164334  4.579952  5.327717
#
#    ...      2012      2013      2014      2015      2016      2017      2018  \
# 0  ... -1.035375  6.429817 -0.020479  3.543630  2.116716  5.482371  1.267218
# 1  ...  0.923067  4.200209  3.984387  2.952845  2.217017  2.557135  2.485244
#
#        2019       2020      2021
# 0 -2.085600 -22.318948       NaN
# 1  2.025941  -2.886856  4.303667
#
# [2 rows x 66 columns]

# %%
df2= df.drop(['Indicator Name', 'Indicator Code'], axis=1)

# %% [markdown]
# by default, axis=0

# %%
df2
# Out:
#                     Country Name Country Code  1960      1961      1962  \
# 0                          Aruba          ABW   NaN       NaN       NaN
# 1    Africa Eastern and Southern          AFE   NaN  0.239594  7.980768
# 2                    Afghanistan          AFG   NaN       NaN       NaN
# 3     Africa Western and Central          AFW   NaN  1.848752  3.770220
# 4                         Angola          AGO   NaN       NaN       NaN
# ..                           ...          ...   ...       ...       ...
# 261                       Kosovo          XKX   NaN       NaN       NaN
# 262                  Yemen, Rep.          YEM   NaN       NaN       NaN
# 263                 South Africa          ZAF   NaN  3.844734  6.177931
# 264                       Zambia          ZMB   NaN  1.361382 -2.490839
# 265                     Zimbabwe          ZWE   NaN  6.316157  1.434471
#
#          1963       1964       1965      1966      1967  ...       2012  \
# ...

# %%
df2.stack()
# Out:
# 0    Country Name        Aruba
#      Country Code          ABW
#      1987            16.078431
#      1988            18.648649
#      1989            12.129841
#                        ...
# 265  2017             4.709492
#      2018             4.824211
#      2019            -6.144236
#      2020            -6.248748
#      2021              5.84942
# Length: 12955, dtype: object

# %%
df2.stack().reset_index()
# Out:
#        level_0       level_1          0
# 0            0  Country Name      Aruba
# 1            0  Country Code        ABW
# 2            0          1987  16.078431
# 3            0          1988  18.648649
# 4            0          1989  12.129841
# ...        ...           ...        ...
# 12950      265          2017   4.709492
# 12951      265          2018   4.824211
# 12952      265          2019  -6.144236
# 12953      265          2020  -6.248748
# 12954      265          2021    5.84942
#
# [12955 rows x 3 columns]

# %%
df3= df2.set_index(['Country Name', 'Country Code']).stack().reset_index()

# %%
df4= df3.rename(columns={'level_2':'Year', 0:'GDP growth (annual %)'})

# %%
df4
# Out:
#       Country Name Country Code  Year  GDP growth (annual %)
# 0            Aruba          ABW  1987              16.078431
# 1            Aruba          ABW  1988              18.648649
# 2            Aruba          ABW  1989              12.129841
# 3            Aruba          ABW  1990               3.961402
# 4            Aruba          ABW  1991               7.962872
# ...            ...          ...   ...                    ...
# 12418     Zimbabwe          ZWE  2017               4.709492
# 12419     Zimbabwe          ZWE  2018               4.824211
# 12420     Zimbabwe          ZWE  2019              -6.144236
# 12421     Zimbabwe          ZWE  2020              -6.248748
# 12422     Zimbabwe          ZWE  2021               5.849420
#
# [12423 rows x 4 columns]

# %%
df4.set_index('Country Name').to_csv('example.csv')

# %% [markdown]
# unstacking

# %%
df3.set_index(['Country Name', 'Country Code','level_2']).unstack()[0]
# Out:
# level_2                                        1961       1962       1963  \
# Country Name                Country Code
# Afghanistan                 AFG                 NaN        NaN        NaN
# Africa Eastern and Southern AFE            0.239594   7.980768   5.164334
# Africa Western and Central  AFW            1.848752   3.770220   7.272440
# Albania                     ALB                 NaN        NaN        NaN
# Algeria                     DZA          -13.605441 -19.685042  34.313729
# ...                                             ...        ...        ...
# West Bank and Gaza          PSE                 NaN        NaN        NaN
# World                       WLD            3.790542   5.316458   5.184865
# Yemen, Rep.                 YEM                 NaN        NaN        NaN
# Zambia                      ZMB            1.361382  -2.490839   3.272393
# Zimbabwe                    ZWE            6.316157   1.434471   6.244345
#
# ...

# %%
pd.read_html('https://ratings.fide.com/top_lists.phtml')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-7b09da45048e> in <module>
# ----> 1 pd.read_html('https://ratings.fide.com/top_lists.phtml')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1111         na_values=na_values,
#    1112         keep_default_na=keep_default_na,
# -> 1113         displayed_only=displayed_only,
#    1114     )
#
# ...

# %% [markdown]
# no tables found on site, may be protected

# %%
pd.read_html('chess_table.html')
# Out:
# [       #                  Name  Fed  Rating  +-  B-Year      Avg12M
#  0      1       Carlsen, Magnus  NOR    2856 NaN    1990    2862 (1)
#  1      2           Ding, Liren  CHN    2811 NaN    1992    2803 (2)
#  2      3   Nepomniachtchi, Ian  RUS    2793 NaN    1990    2778 (5)
#  3      4     Firouzja, Alireza  FRA    2785 NaN    2003    2793 (3)
#  4      5            So, Wesley  USA    2774 NaN    1993    2773 (7)
#  ..   ...                   ...  ...     ...  ..     ...         ...
#  97    98    Bluebaum, Matthias  GER    2647 NaN    1997   2652 (91)
#  98    99       Bacrot, Etienne  FRA    2646 NaN    1983  2644 (105)
#  99   100  Donchenko, Alexander  GER    2646 NaN    1998  2630 (130)
#  100  101         Abasov, Nijat  AZE    2646 NaN    1995  2635 (120)
#  101  102         Mamedov, Rauf  AZE    2646 NaN    1988   2656 (86)
#
#  [102 rows x 7 columns]]

# %% [markdown]
# .dropna will drop null values and rows which contain

# %%
table_list=pd.read_html('chess_table.html')
wiki_list=pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)_per_capita')

# %%
len(table_list),len(wiki_list)
# Out:
# (1, 6)

# %%
s='2862(1)'
s
# Out:
# '2862(1)'

# %%
s.split('2862')[1].replace('(','').replace(')','')
# Out:
# '1'

# %%
chess_df=table_list[0]

# %%
chess_df['Rating last year']= chess_df['Avg12M'].str.split('').str[0].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-9a9fc1f88dbe> in <module>
# ----> 1 chess_df['Rating last year']= chess_df['Avg12M'].str.split('2862').str[0].astype(float)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
# ...

# %%
chess_df['Ranking last year']=chess_df['Avg12M'].str.split('').str[1].str.replace('(','').str.replace(')','')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
chess_df
# Out:
#        #                  Name  Fed  Rating  +-  B-Year      Avg12M  \
# 0      1       Carlsen, Magnus  NOR    2856 NaN    1990    2862 (1)
# 1      2           Ding, Liren  CHN    2811 NaN    1992    2803 (2)
# 2      3   Nepomniachtchi, Ian  RUS    2793 NaN    1990    2778 (5)
# 3      4     Firouzja, Alireza  FRA    2785 NaN    2003    2793 (3)
# 4      5            So, Wesley  USA    2774 NaN    1993    2773 (7)
# ..   ...                   ...  ...     ...  ..     ...         ...
# 97    98    Bluebaum, Matthias  GER    2647 NaN    1997   2652 (91)
# 98    99       Bacrot, Etienne  FRA    2646 NaN    1983  2644 (105)
# 99   100  Donchenko, Alexander  GER    2646 NaN    1998  2630 (130)
# 100  101         Abasov, Nijat  AZE    2646 NaN    1995  2635 (120)
# 101  102         Mamedov, Rauf  AZE    2646 NaN    1988   2656 (86)
#
#     Ranking last year
# 0                   2
# 1                   2
# 2                   2
# 3                   2
# 4                   2
# ...
