# %% [markdown]
# <a href="https://colab.research.google.com/github/hcantekin/hcantekin.github.io/blob/main/Metatest00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
import json

# %%
df = pd.read_csv('MetaReport_test00.csv')

# %%
df.dropna()
# Out:
#         ID         page_name ad_creation_time  \
# 0        1  The Labour Party       2021-12-16
# 1        2  The Labour Party       2021-12-16
# 2        3  The Labour Party       2021-12-16
# 3        4  The Labour Party       2021-12-16
# 5        6  The Labour Party       2021-12-14
# ...    ...               ...              ...
# 5814  5815  The Labour Party       2021-01-11
# 5815  5816  The Labour Party       2021-01-11
# 5816  5817  The Labour Party       2021-01-11
# 5817  5818  The Labour Party       2021-01-11
# 5818  5819  The Labour Party       2021-01-11
#
#                                demographic_distribution  \
# 0     {"age":"18-24","gender":"female","percentage":...
# 1     {"age":"25-34","gender":"unknown","percentage"...
# 2     {"age":"25-34","gender":"unknown","percentage"...
# 3     {"age":"45-54","gender":"unknown","percentage"...
# 5     {"age":"65+","gender":"male","percentage":0.05...
# ...                                                 ...
# ...
