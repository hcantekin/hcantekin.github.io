# %% [markdown]
# <a href="https://colab.research.google.com/github/hcantekin/hcantekin.github.io/blob/main/data_USdems19_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import json 
from google.colab import files
import os

# %%
df = pd.read_csv('USDems19_22.csv')
df
# Out:
#               page_name ad_delivery_start_time ad_delivery_stop_time   durn  \
# 0      Democratic Party             2021-03-07            2021-03-19  12.00
# 1      Democratic Party             2021-03-07            2021-03-16   9.00
# 2      Democratic Party             2021-03-07            2021-03-18  11.00
# 3      Democratic Party             2021-03-07            2021-03-18  11.00
# 4      Democratic Party             2021-03-07            2021-03-10   3.00
# ...                 ...                    ...                   ...    ...
# 88830  Democratic Party             2021-03-07            2021-03-09   2.00
# 88831  Democratic Party             2021-03-07            2021-03-13   6.00
# 88832  Democratic Party             2021-03-07            2021-03-18  11.00
# 88833  Democratic Party             2021-03-07            2021-03-18  11.00
# 88834  Democratic Party             2021-03-07            2021-03-18  11.00
#
# ...

# %%
del df['durn']

# %%
df1= df.dropna()
df1
# Out:
#               page_name ad_delivery_start_time ad_delivery_stop_time duration  \
# 0      Democratic Party             2021-03-07            2021-03-19    13.00
# 1      Democratic Party             2021-03-07            2021-03-16    10.00
# 2      Democratic Party             2021-03-07            2021-03-18    12.00
# 3      Democratic Party             2021-03-07            2021-03-18    12.00
# 5      Democratic Party             2021-03-07            2021-03-12     6.00
# ...                 ...                    ...                   ...      ...
# 88821  Democratic Party             2021-03-07            2021-03-09     3.00
# 88825  Democratic Party             2021-03-07            2021-03-19    13.00
# 88827  Democratic Party             2021-03-07            2021-03-09     3.00
# 88831  Democratic Party             2021-03-07            2021-03-13     7.00
# 88834  Democratic Party             2021-03-07            2021-03-18    12.00
#
# ...

# %%
df1['distribution'] = df1['distribution'].astype('string')
df1['region'] = df1['region'].astype('string')
# Out:
# <ipython-input-9-be94494ad313>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['distribution'] = df1['distribution'].astype('string')
# <ipython-input-9-be94494ad313>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['region'] = df1['region'].astype('string')

# %%
print(df1.dtypes)

df1
# Out:
# page_name                 object
# ad_delivery_start_time    object
# ad_delivery_stop_time     object
# duration                  object
# region                    string
# distribution              string
# dtype: object
#               page_name ad_delivery_start_time ad_delivery_stop_time duration  \
# 0      Democratic Party             2021-03-07            2021-03-19    13.00
# 1      Democratic Party             2021-03-07            2021-03-16    10.00
# 2      Democratic Party             2021-03-07            2021-03-18    12.00
# 3      Democratic Party             2021-03-07            2021-03-18    12.00
# 5      Democratic Party             2021-03-07            2021-03-12     6.00
# ...                 ...                    ...                   ...      ...
# 88821  Democratic Party             2021-03-07            2021-03-09     3.00
# 88825  Democratic Party             2021-03-07            2021-03-19    13.00
# ...

# %% [markdown]
# del df1['Distribution ']

# %%
df2= df1[df1['distribution'].str.contains("percentage:1}")]
df2
# Out:
#               page_name ad_delivery_start_time ad_delivery_stop_time duration  \
# 1180   Democratic Party             2020-11-03            2020-11-04     2.00
# 1181   Democratic Party             2020-11-03            2020-11-04     2.00
# 1182   Democratic Party             2020-11-03            2020-11-04     2.00
# 1183   Democratic Party             2020-11-03            2020-11-04     2.00
# 1187   Democratic Party             2020-11-03            2020-11-03     1.00
# ...                 ...                    ...                   ...      ...
# 84403  Democratic Party             2021-04-09            2021-04-09     1.00
# 84404  Democratic Party             2021-04-09            2021-04-09     1.00
# 84405  Democratic Party             2021-04-09            2021-04-10     2.00
# 84406  Democratic Party             2021-04-09            2021-04-10     2.00
# 84407  Democratic Party             2021-04-09            2021-04-10     2.00
#
# ...

# %%
df2['region'] = df2['region'].str.split(':').str[1].str.replace('{"region"','').str.replace('"','')
df2
# Out:
# <ipython-input-13-3a7167b87e4e>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2['region'] = df2['region'].str.split(':').str[1].str.replace('{"region"','').str.replace('"','')
# <ipython-input-13-3a7167b87e4e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['region'] = df2['region'].str.split(':').str[1].str.replace('{"region"','').str.replace('"','')
#               page_name ad_delivery_start_time ad_delivery_stop_time duration  \
# 1180   Democratic Party             2020-11-03            2020-11-04     2.00
# 1181   Democratic Party             2020-11-03            2020-11-04     2.00
# 1182   Democratic Party             2020-11-03            2020-11-04     2.00
# ...

# %%
df3 = df2['region'].value_counts()
df4 = pd.DataFrame(df3)
df5= df4.reset_index()
df6= df5.rename(columns={'index': 'State', 'delivery_by_region': 'Number of Ads'})
df6
# Out:
#              State  region
# 0        Wisconsin    1884
# 1          Arizona    1836
# 2          Florida    1730
# 3         Michigan    1726
# 4     Pennsylvania    1629
# 5          Georgia    1446
# 6   North Carolina    1098
# 7        Minnesota     813
# 8           Nevada     770
# 9             Iowa     666
# 10        Colorado     354
# 11   New Hampshire     354
# 12        Nebraska     351
# 13        Virginia     266
# 14           Texas      88
# 15   Massachusetts       8
# 16        New York       7
# 17      California       6
# 18            Ohio       1

# %%
USDems20 = list(df5.T.to_dict().values())
open('USDems20.json', 'w').write(json.dumps(USDems20))
# Out:
# 2302
