# %% [markdown]
# <a href="https://colab.research.google.com/github/hcantekin/hcantekin.github.io/blob/main/wide2long_eg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('example_widedf.csv')
df
# Out:
#      sector  2000  2001  2002  2003  2004  2005  2006  2007  2008  2009
# 0  sector 1     3     3     3     3     3     3     3     3     3     3
# 1  sector 2    43    43    43    43    43    43    43    43    43    43
# 2  sector 3     4     4     4     4     4     4     4     4     4     4
# 3  sector 4     4     4     4     4     4     4     4     4     4     4
# 4  sector 5     4     4     4     4     4     4     4     4     4     4

# %%
df2 = df.stack().reset_index()
df2

# %%
df3= df.set_index(['sector']).stack().reset_index()
df3
# Out:
#       sector level_1   0
# 0   sector 1    2000   3
# 1   sector 1    2001   3
# 2   sector 1    2002   3
# 3   sector 1    2003   3
# 4   sector 1    2004   3
# 5   sector 1    2005   3
# 6   sector 1    2006   3
# 7   sector 1    2007   3
# 8   sector 1    2008   3
# 9   sector 1    2009   3
# 10  sector 2    2000  43
# 11  sector 2    2001  43
# 12  sector 2    2002  43
# 13  sector 2    2003  43
# 14  sector 2    2004  43
# 15  sector 2    2005  43
# 16  sector 2    2006  43
# 17  sector 2    2007  43
# 18  sector 2    2008  43
# 19  sector 2    2009  43
# 20  sector 3    2000   4
# 21  sector 3    2001   4
# 22  sector 3    2002   4
# 23  sector 3    2003   4
# 24  sector 3    2004   4
# 25  sector 3    2005   4
# 26  sector 3    2006   4
# 27  sector 3    2007   4
# 28  sector 3    2008   4
# 29  sector 3    2009   4
# 30  sector 4    2000   4
# 31  sector 4    2001   4
# 32  sector 4    2002   4
# 33  sector 4    2003   4
# 34  sector 4    2004   4
# 35  sector 4    2005   4
# ...

# %%
df4 = df3.rename(columns={'level_1': 'Year', '0': 'value'})

df4
# Out:
#       sector  Year   0
# 0   sector 1  2000   3
# 1   sector 1  2001   3
# 2   sector 1  2002   3
# 3   sector 1  2003   3
# 4   sector 1  2004   3
# 5   sector 1  2005   3
# 6   sector 1  2006   3
# 7   sector 1  2007   3
# 8   sector 1  2008   3
# 9   sector 1  2009   3
# 10  sector 2  2000  43
# 11  sector 2  2001  43
# 12  sector 2  2002  43
# 13  sector 2  2003  43
# 14  sector 2  2004  43
# 15  sector 2  2005  43
# 16  sector 2  2006  43
# 17  sector 2  2007  43
# 18  sector 2  2008  43
# 19  sector 2  2009  43
# 20  sector 3  2000   4
# 21  sector 3  2001   4
# 22  sector 3  2002   4
# 23  sector 3  2003   4
# 24  sector 3  2004   4
# 25  sector 3  2005   4
# 26  sector 3  2006   4
# 27  sector 3  2007   4
# 28  sector 3  2008   4
# 29  sector 3  2009   4
# 30  sector 4  2000   4
# 31  sector 4  2001   4
# 32  sector 4  2002   4
# 33  sector 4  2003   4
# 34  sector 4  2004   4
# 35  sector 4  2005   4
# 36  sector 4  2006   4
# 37  sector 4  2007   4
# 38  sector 4  2008   4
# ...
